# %%
from pathlib import Path
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import torch
import re

# %%
plt.rcParams['figure.figsize'] = 22, 8

# %%
result = pd.DataFrame()
# 
for file in Path('outputs').rglob('model_final.pt'):
# for file in Path('outputs').rglob('model_epoch_399'):
# for file in Path().rglob('model_epoch_5799.pt'):
    file = str(file)
    alpha = None
    if 'alpha' in file:
        alpha = re.findall('alpha-[0-9].{2,3}', file)[0]
        alpha = float(alpha[-4:])

    sample_size = re.findall('train[0-9].{2,3}', file)[0]
    sample_size = sample_size[-4:]
    _, _, _, dataset, arch, *_ = re.findall('[a-z0-9]+', file)
    method = re.findall('(?:[a-z]_?)+',file)
    method = method[11] if 'alpha' in method else method[9]
    print(method)
    # if not (method == 'freddy' or method == 'random'):
    #     continue
    print( alpha, sample_size)
    
    f = torch.load(file, map_location=torch.device('cpu'))
    try:
        plt.hist(f['selected'], bins=50)
        plt.yscale('log')
        # plt.axhline(5000)
        plt.show()
        #############
        selected = f['epoch_selection']
        #############

        # plt.scatter(f['selected'], f['importance'])
        plt.scatter(f['reaL_error'], f['importance'])
        plt.show()
    except:
        pass
    tmp = f['hist']
    tmp = pd.DataFrame.from_records(tmp)
    if method == 'None':
        sample_size = 1
    # print(f['grad_norm'])
    # tmp['epoch'] = range(len(tmp))
    tmp['alpha'] = float(alpha) if alpha else None
    tmp['dataset'] = dataset
    tmp['arch'] = arch
    tmp['sample_size'] = float(sample_size)
    tmp['method'] = method
    result = pd.concat([tmp, result])
# result[result.method.isna()] = 'full dataset'
# result = result[result.epoch<20]
result
# Out:
# random
# None 0.10
# freddy
# 1.5 0.10
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_4053/1112081887.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   f = torch.load(file, map_location=torch.device('cpu'))
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_4053/1112081887.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   f = torch.load(file, map_location=torch.device('cpu'))
# full
# None 0.10
# crest
# None 0.10
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_4053/1112081887.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat([tmp, result])
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_4053/1112081887.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   f = torch.load(file, map_location=torch.device('cpu'))
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_4053/1112081887.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat([tmp, result])
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_4053/1112081887.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   f = torch.load(file, map_location=torch.device('cpu'))
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_4053/1112081887.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat([tmp, result])
#       train_loss  train_acc  val_loss  val_acc  grad_norm  epoch  alpha  \
# 0       3.602538   0.096094  3.427709   0.0925   6.262950      0    NaN
# 1       2.390637   0.134437  2.147121   0.1965   2.191204      1    NaN
# 2       2.019397   0.220308  1.962362   0.2717   2.289035      2    NaN
# 3       1.895131   0.253626  1.886715   0.2819   2.810668      3    NaN
# 4       1.781243   0.282219  1.780471   0.3480   2.709201      4    NaN
# ...          ...        ...       ...      ...        ...    ...    ...
# 1995    0.416642   0.857600  0.486495   0.8347   2.849290   1995    NaN
# 1996    0.404390   0.860000  0.489044   0.8324   1.137713   1996    NaN
# 1997    0.408453   0.858200  0.492071   0.8327   1.580352   1997    NaN
# 1998    0.439827   0.848800  0.485314   0.8360   1.689357   1998    NaN
# 1999    0.433875   0.847800  0.489191   0.8354   1.124391   1999    NaN
#
#      dataset arch  sample_size  method  avg_importance  reaL_error
# 0        lr0    1          0.1   crest             NaN         NaN
# 1        lr0    1          0.1   crest             NaN         NaN
# 2        lr0    1          0.1   crest             NaN         NaN
# 3        lr0    1          0.1   crest             NaN         NaN
# 4        lr0    1          0.1   crest             NaN         NaN
# ...      ...  ...          ...     ...             ...         ...
# 1995     lr0    1          0.1  random             NaN         NaN
# 1996     lr0    1          0.1  random             NaN         NaN
# 1997     lr0    1          0.1  random             NaN         NaN
# 1998     lr0    1          0.1  random             NaN         NaN
# 1999     lr0    1          0.1  random             NaN         NaN
#
# [6050 rows x 13 columns]

# %%
alpha = [.15, .25, .5, .75, 1, 2, 3, 5, 10, 20]

i = 1.5
print(i)
# fig, ax = plt.subplots(3, 1)
fig, ax = plt.subplots(2,1, sharex=True)
sns.lineplot(
    result,
    x='epoch', 
    y='val_acc', 
    hue='method',
    style='method',
    alpha=.7,
    ax=ax[0]
)
sns.lineplot(
    result,
    x='epoch', 
    y='grad_norm', 
    hue='method',
    style='method',
    alpha=.7,
    ax=ax[1]
)
# ax[1].set_yscale('log')
# ax[1].set_xlim([0,150])
# for v in selected:
#     ax[1].axvline(v)

# sns.lineplot(
#     result,
#     x='epoch', 
#     y='val_loss', 
#     hue='method',
#     style='method',
#     alpha=.7,
#     ax=ax[1]
# )
# sns.lineplot(
#     result,
#     x='epoch', 
#     y='grad_norm', 
#     hue='method',
#     style='method',
#     alpha=.7,
#     ax=ax[2]
# )

plt.tight_layout()
plt.show()
# Out:
# 1.5

# %%
alpha = [.15, .25, .5, .75, 1, 2, 3, 5, 10, 20]

i = 1.5
print(i)
fig, ax = plt.subplots(4,1, sharex=True)

sns.lineplot(
    result[
        (result.method=='random') |
        (result.method=='freddy')
    ],
    x='epoch', 
    y='val_acc', 
    hue='method',
    style='method',
    alpha=.7,
    ax=ax[0]
)
ax[0].set_xlim([0,  250])
# for v in selected:
#     ax[0].axvline(v, c='y')
    
sns.lineplot(
    result[
        (result.method=='random') |
        (result.method=='freddy')
    ],
    x='epoch', 
    y='val_loss', 
    hue='method',
    style='method',
    alpha=.7,
    ax=ax[1]
)
for v in selected:
    ax[1].axvline(v, c='y')

sns.lineplot(
    result[
        (result.method=='random') |
        (result.method=='freddy')
    ],
    x='epoch', 
    y='grad_norm', 
    hue='method',
    style='method',
    alpha=.7,
    ax=ax[2]
)
for v in selected:
    ax[2].axvline(v, c='y')
    
sns.lineplot(
    result[
        (result.method=='random') |
        (result.method=='freddy')
    ],
    x='epoch', 
    y='avg_importance', 
    hue='method',
    style='method',
    alpha=.7,
    ax=ax[3]
)
for v in selected:
    ax[3].axvline(v, c='y')

# ax[1].set_yscale('log')
# v=15
# ax[0].axvline(v, c='y')
# ax[1].axvline(v, c='y')
# ax[2].axvline(v, c='y')
# ax[3].axvline(v, c='y')

plt.tight_layout()
plt.show()
# Out:
# 1.5

# %%
result
# Out:
#       train_loss  train_acc  val_loss  val_acc  grad_norm  epoch  alpha  \
# 0       3.602538   0.096094  3.427709   0.0925   6.262950      0    NaN
# 1       2.390637   0.134437  2.147121   0.1965   2.191204      1    NaN
# 2       2.019397   0.220308  1.962362   0.2717   2.289035      2    NaN
# 3       1.895131   0.253626  1.886715   0.2819   2.810668      3    NaN
# 4       1.781243   0.282219  1.780471   0.3480   2.709201      4    NaN
# ...          ...        ...       ...      ...        ...    ...    ...
# 1995    0.416642   0.857600  0.486495   0.8347   2.849290   1995    NaN
# 1996    0.404390   0.860000  0.489044   0.8324   1.137713   1996    NaN
# 1997    0.408453   0.858200  0.492071   0.8327   1.580352   1997    NaN
# 1998    0.439827   0.848800  0.485314   0.8360   1.689357   1998    NaN
# 1999    0.433875   0.847800  0.489191   0.8354   1.124391   1999    NaN
#
#      dataset arch  sample_size  method  avg_importance  reaL_error
# 0        lr0    1          0.1   crest             NaN         NaN
# 1        lr0    1          0.1   crest             NaN         NaN
# 2        lr0    1          0.1   crest             NaN         NaN
# 3        lr0    1          0.1   crest             NaN         NaN
# 4        lr0    1          0.1   crest             NaN         NaN
# ...      ...  ...          ...     ...             ...         ...
# 1995     lr0    1          0.1  random             NaN         NaN
# 1996     lr0    1          0.1  random             NaN         NaN
# 1997     lr0    1          0.1  random             NaN         NaN
# 1998     lr0    1          0.1  random             NaN         NaN
# 1999     lr0    1          0.1  random             NaN         NaN
#
# [6050 rows x 13 columns]

# %%
sns.pairplot(
    result[result.method=='freddy'], 
    y_vars=['val_acc', 'train_acc', 'avg_importance', 'reaL_error'], 
    x_vars=['train_loss', 'val_loss', 'grad_norm' , 'epoch']
)
