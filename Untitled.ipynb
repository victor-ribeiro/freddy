# %%
from pathlib import Path
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import torch
import re

# %%
plt.rcParams['figure.figsize'] = 22, 8

# %%
result = pd.DataFrame()

for file in Path().rglob('model_final.pt'):
    f = torch.load(file, map_location=torch.device('cpu'))
    tmp = f['hist']
    tmp = pd.DataFrame.from_records(tmp)
    file = str(file)
    alpha = None
    if 'alpha' in file:
        alpha = re.findall('alpha-[0-9].{2,3}', file)[0]
        alpha = float(alpha[-4:])

    sample_size = re.findall('train[0-9].{2,3}', file)[0]
    sample_size = sample_size[-4:]
    _, dataset, arch, *_ = re.findall('[a-z0-9]+', file)
    
    # print(file, end='\t')
    method = re.findall('(?:[a-z]_?)+',file)
    # print(method)
    # method = method[9] if alpha in method else method[11]
    print(method[9], alpha, sample_size)
    method = method[11] if 'alpha' in method else method[9]
    
    if method == 'None':
        sample_size = 1
    # print(f['grad_norm'])
    tmp['epoch'] = range(len(tmp))
    tmp['alpha'] = float(alpha) if alpha else None
    tmp['dataset'] = dataset
    tmp['arch'] = arch
    tmp['sample_size'] = float(sample_size)
    tmp['method'] = method
    result = pd.concat([tmp, result])
# result[result.method.isna()] = 'full dataset'
result = result[result.epoch<20]
# Out:
# batchnummul None 0.10
# dataset None 0.10
# random None 0.10
# full None 0.10
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_2027/1977992111.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   f = torch.load(file, map_location=torch.device('cpu'))
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_2027/1977992111.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   f = torch.load(file, map_location=torch.device('cpu'))
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_2027/1977992111.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   f = torch.load(file, map_location=torch.device('cpu'))
# /var/folders/zp/12jqqjln6qdgg08yb4x3z2x00000gn/T/ipykernel_2027/1977992111.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   f = torch.load(file, map_location=torch.device('cpu'))

# %%
# fig, axes = plt.subplots(1, 1)

for i in result.loc[result.alpha.notna(), 'alpha'].unique():
    print(i)
    sns.lineplot(
        result[
            (result.alpha == i) |
            (result.alpha.isna()) 
        ], 
        x='epoch', 
        y='val_acc', 
        hue='method',
        style='method',
        alpha=.7
        # ax=ax
    )
    plt.ylim([0, .5])

    
    # plt.tight_layout()
    plt.show()

# %%
result
# Out:
#     train_loss  train_acc  val_loss  val_acc       grad_norm  epoch alpha  \
# 0     3.378279    0.08762  3.100436   0.0875  tensor(4.1193)      0  None
# 1     2.114757    0.21762  1.906594   0.2856  tensor(0.9280)      1  None
# 2     1.749161    0.34658  1.636421   0.3962  tensor(1.1315)      2  None
# 3     1.579802    0.41178  1.484216   0.4488  tensor(1.4156)      3  None
# 4     1.471956    0.45772  1.527922   0.4459  tensor(1.8143)      4  None
# ..         ...        ...       ...      ...             ...    ...   ...
# 15    1.549831    0.42860  6.054004   0.1168  tensor(4.7001)     15  None
# 16    1.571946    0.42060  4.230878   0.2401  tensor(3.9865)     16  None
# 17    1.531315    0.44160  3.986690   0.1821  tensor(4.3172)     17  None
# 18    1.532477    0.43660  3.865394   0.2167  tensor(2.9600)     18  None
# 19    1.484433    0.45320  8.402365   0.1580  tensor(2.4983)     19  None
#
#      dataset      arch  sample_size       method
# 0    cifar10  resnet20          0.1         full
# 1    cifar10  resnet20          0.1         full
# 2    cifar10  resnet20          0.1         full
# 3    cifar10  resnet20          0.1         full
# 4    cifar10  resnet20          0.1         full
# ..       ...       ...          ...          ...
# 15  resnet20       lr0          0.1  batchnummul
# 16  resnet20       lr0          0.1  batchnummul
# 17  resnet20       lr0          0.1  batchnummul
# 18  resnet20       lr0          0.1  batchnummul
# 19  resnet20       lr0          0.1  batchnummul
#
# [80 rows x 11 columns]
